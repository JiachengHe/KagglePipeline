# %%
devtools::load_all("../KagglePipeline")
library(readr)
library(dplyr)
# Out:
# Loading KagglePipeline

# %%
df_train = read_csv("../Titanic/data/train.csv")
df_test = read_csv("../Titanic/data//test.csv")
# Out:
# Parsed with column specification:
# cols(
#   PassengerId = col_integer(),
#   Survived = col_integer(),
#   Pclass = col_integer(),
#   Name = col_character(),
#   Sex = col_character(),
#   Age = col_double(),
#   SibSp = col_integer(),
#   Parch = col_integer(),
#   Ticket = col_character(),
#   Fare = col_double(),
#   Cabin = col_character(),
#   Embarked = col_character()
# )
# Parsed with column specification:
# cols(
#   PassengerId = col_integer(),
#   Pclass = col_integer(),
#   Name = col_character(),
#   Sex = col_character(),
#   Age = col_double(),
#   SibSp = col_integer(),
#   Parch = col_integer(),
#   Ticket = col_character(),
#   Fare = col_double(),
#   Cabin = col_character(),
#   Embarked = col_character()
# )

# %%
df <- bind_rows(mutate(df_train, train_or_test = "train"),
                mutate(df_test, train_or_test = "test"))
df$Survived <- factor(df$Survived)
source("../Titanic/Titanic_FE.R")

# %%
df <- df %>%
  select(-Name, -Ticket, -Cabin, -Surname, -FamilyID) %>%
  factorize(list("Pclass", "Sex", "Embarked", "Cabin_letter", "Title", "FamilySize", "SibSp", "Parch"))

# %%
df <- random_impute(df, yVar = "Survived")

# %%
automate_factor_plot(df, yVar = "Survived")
# Out:
# Press Enter for next plot:
# [1] 1
#
# Average Survived for Pclass
# Press Enter for next plot:
# plot without title
# Count of each Pclass[1] 2
# plot without title
# Average Survived for Sex
# Press Enter for next plot:
# plot without title
# Count of each Sex[1] 3
# plot without title
# Average Survived for SibSp
# Press Enter for next plot:
# plot without title
# Count of each SibSp[1] 4
# plot without title
# Average Survived for Parch
# Press Enter for next plot:
# plot without title
# Count of each Parch[1] 5
# plot without title
# Average Survived for Embarked
# Press Enter for next plot:
# plot without title
# Count of each Embarked[1] 6
# plot without title
# Average Survived for Cabin_letter
# Press Enter for next plot:
# plot without title
# Count of each Cabin_letter[1] 7
# plot without title
# Average Survived for FamilySize
# Press Enter for next plot:
# plot without title
# Count of each FamilySize[1] 8
# plot without title
# Average Survived for Title
# Press Enter for next plot:
# plot without title
# Count of each Title[1] 9
# plot without title
# Average Survived for Kid
# plot without title
# Count of each Kid
# plot without title

# %%
automate_numeric_plot(df, yVar = "Survived")
# Out:
# Press Enter for next plot:
# [1] 1
#
# Scatter plot of Survived with PassengerId
# plot without title
# Density of PassengerId
# Press Enter for next plot:
# plot without title
# Histogram of PassengerId[1] 2
# plot without title
# Scatter plot of Survived with Age
# plot without title
# Density of Age
# Press Enter for next plot:
# plot without title
# Histogram of Age[1] 3
# plot without title
# Scatter plot of Survived with Fare
# plot without title
# Density of Fare
# plot without title
# Histogram of Fare
# plot without title
